# %%
from PyPDF2 import PdfReader
import pandas as pd

# %%
def pdf_to_squad(pdf_file):
    # Open the PDF file
    pdf = PdfReader(pdf_file)

    # Initialize the QA squad dataset list
    squad_dataset = []

    # Get the number of pages in the PDF
    num_pages = len(pdf.pages)

    # Loop through each page in the PDF
    for i in range(num_pages):
        # Get the text from each page
        page = pdf.pages[i].extract_text()
        
        # Split the text into sentences
        sentences = page.split('.')
        
        # Loop through each sentence to create a QA pair
        for sentence in sentences:
            try:
                # Split the sentence into question and answer
                question, answer = sentence.split('?')
                
                # Add the QA pair to the squad dataset list
                squad_dataset.append({
                    'context': page,
                    'question': question,
                    'answer': answer
                })
            except ValueError:
                # If the sentence does not contain a question and answer, skip it
                continue
    
    return squad_dataset

# %%
squad_dataset = pdf_to_squad('RH-1-productfaq.pdf')

# %%
squad_dataset = pd.DataFrame(squad_dataset)

# %%
squad_dataset
# Out:
#                                                                             context  \
# 0   Home Products Red Hat OpenShift Re…   \nRed Hat OpenShift\nService on ...
# 1   Home Products Red Hat OpenShift Re…   \nRed Hat OpenShift\nService on ...
# 2   Home Products Red Hat OpenShift Re…   \nRed Hat OpenShift\nService on ...
# 3   Home Products Red Hat OpenShift Re…   \nRed Hat OpenShift\nService on ...
# 4   Everything you need to deploy and manage containers is bundled with ROSA,\ni...
# ..                                                                              ...
# 70  Does the ROSA CLI accept Multi-region KMS keys for EBS\nencryption?\nNot at ...
# 71  Does the ROSA CLI accept Multi-region KMS keys for EBS\nencryption?\nNot at ...
# 72  Does the ROSA CLI accept Multi-region KMS keys for EBS\nencryption?\nNot at ...
# 73  Does the ROSA CLI accept Multi-region KMS keys for EBS\nencryption?\nNot at ...
# 74  Does the ROSA CLI accept Multi-region KMS keys for EBS\nencryption?\nNot at ...
#
#                                                                            question  \
# 0           \nGeneral questions\nWhat does Red Hat OpenShift Service on AWS include
# 1   \nHow is Red Hat OpenShift Service on AWS different from Red Hat\nOpenShift ...
# 2   \nHow Is Red Hat OpenShift Service on AWS different from Red Hat\nOpenShift ...
# 3   \nWhat are the differences between Red Hat OpenShift Service on\nAWS and Kub...
# 4        \nWill Red Hat OpenShift Service on AWS integrate with other AWS\nservices
# ..                                                                              ...
# 70               \nCan I define a custom domain and certificate for my applications
# 71                                   \nHow are the ROSA domain certificates managed
# 72                                        com)\nWhat features are upcoming for ROSA
# 73           ht/rosa-roadmap\nWhat kind of instances are supported for worker nodes
# 74         \nWhat is the maximum number of worker nodes that a cluster can\nsupport
#
#                                                                              answer
# 0   \nEach Red Hat OpenShift Service on AWS cluster comes with a fully-managed\n...
# 1   \nRed Hat OpenShift Service on AWS delivers a turnkey application platform,\...
# 2   \nRed Hat OpenShift Service on AWS is a fully managed implementation of\nOpe...
# 3                                                               \nRed Hat OpenShift
# 4                                                                             \nYes
# ..                                                                              ...
# 70                                                                            \nYes
# 71  \nRed Hat infrastructure (Hive) manages certificate rotation for default app...
# 72                           \nThe current ROSA roadmap can be seen at: https://red
# 73  \nSee AWS compute types in the service definition for the up to date list of...
# 74                     \nThe maximum number of worker nodes is 180 per ROSA cluster
#
# [75 rows x 3 columns]
