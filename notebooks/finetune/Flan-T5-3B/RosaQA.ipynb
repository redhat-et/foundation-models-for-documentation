# %% [markdown]
# # Low rank finetune FLAN-T5 on ROSA dataset

# %% [markdown]
# Fine tuning models where all its parameters are changed is expensive with very large models. For perspective, a T4 16GB GPU will barely be able to fine tune a 1B parameter model. Large models like GPT-3 have 175B and more parameters. Therefore, in this notebook we try efficient ways of adapting a model.
#
# In this notebook we will see how to use `peft` , `transformers` & `bitsandbytes` to fine-tune `flan-t5-large`. The `peft` package allows us to use low rank adaption method of training less than 1% of the original model parameters. The [paper](https://arxiv.org/abs/2106.09685) illustrates how it is comparable to a full training.
#
# More information about the implementation of `peft` can be found [here](https://github.com/huggingface/peft). This approach allows us to fine tune a 3B parameter model on a single T4 GPU.
#
# As an experiment, we will try finetuning it on the ROSA QA dataset.
#
# Inspired from Sources [1](https://github.com/huggingface/peft/blob/main/examples/int8_training/Finetune_flan_t5_large_bnb_peft.ipynb) and [2](https://www.philschmid.de/fine-tune-flan-t5-peft).

# %% [markdown]
# # Install requirements

# %%
## Imports
import os
import torch
from datasets import load_dataset, Dataset
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from peft import LoraConfig, get_peft_model, TaskType
from peft import prepare_model_for_int8_training
from peft import PeftModel, PeftConfig
from transformers import TrainingArguments, Trainer
from transformers import DataCollatorForSeq2Seq
from datasets import concatenate_datasets
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import MarkdownTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
import pandas as pd
import numpy as np

# %%
# Select CUDA device index
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# Utility functions
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %% [markdown]
# # Load model and ROSA dataset

# %%
model_name = "ybelkada/flan-t5-xl-sharded-bf16"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, load_in_8bit=True, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
rosa_df = pd.read_csv("../data/processed/dataset-qa/final-ds.csv").rename(columns={'Unnamed: 0':'id'})
rosa_dt = Dataset.from_pandas(rosa_df)
rosa_dt
# Out:
# Dataset({
#     features: ['id', 'Question', 'Context', 'Answer', 'Source'],
#     num_rows: 7560
# })

# %%
rosa_df.sample(5)
# Out:
#       id                                           Question  \
# 1698   4  What privileges does the admin role need to li...
# 4699   7        How do I configure the monitoring stack? \n
# 5096  21  How do I manually link an existing gateway to ...
# 5289   1                   What is the ROSA CLI used for?\n
# 5294   6  How do I deploy a ROSA with AWS Security Token...
#
#                                                 Context  \
# 1698  `iam:ListPolicyTags`: This permission allows t...
# 4699  Configuring the monitoring stack: This step in...
# 5096  Manually linking an existing gateway to a Gate...
# 5289  ROSA CLI (`rosa`): This method allows users to...
# 5294  Creating a Cluster Using Customizations: Users...
#
#                                                  Answer  \
# 1698  The admin role needs the `iam:ListPolicyTags` ...
# 4699  To configure the monitoring stack, follow the ...
# 5096  To manually link an existing gateway to a Gate...
# 5289  The ROSA CLI is used to create Operator roles ...
# 5294  Deploy a ROSA with AWS Security Token Service ...
#
#                                                  Source
# 1698  ../data/processed/dataset-qa/rosa-docs-rosa_ar...
# 4699  ../data/processed/dataset-qa/rosa-docs-rosa_ge...
# 5096  ../data/processed/dataset-qa/rosa-docs-service...
# 5289  ../data/processed/dataset-qa/rosa-docs-rosa_in...
# 5294  ../data/processed/dataset-qa/rosa-docs-rosa_in...

# %%
validation_df = pd.read_csv("../../../data/processed/validation_data.csv").rename(columns={'Unnamed: 0':'id'})
validation_dt = Dataset.from_pandas(validation_df)
validation_dt
# Out:
# Dataset({
#     features: ['id', 'Question', 'Answer'],
#     num_rows: 65
# })

# %%
validation_df.sample(5)
# Out:
#     id                                           Question  \
# 42  42  What infrastructure is provisioned as part of ...
# 19  19  Which compliance certifications does ROSA have...
# 14  14  Is there a discount if I have unused OCP subsc...
# 41  41  How is etcd encryption configured in a ROSA cl...
# 3    3  What are the differences between Red Hat OpenS...
#
#                                                Answer
# 42  ROSA makes use of a number of different cloud ...
# 19  Red Hat OpenShift Service on AWS is currently ...
# 14  Yes! Customers migrating non-ROSA OpenShift wo...
# 41  The same as in OCP. The aescbc cypher is used ...
# 3   Everything you need to deploy and manage conta...

# %% [markdown]
# # Preprocess

# %%
tokenized_inputs = rosa_dt.map(lambda x: tokenizer(x["Question"],
                                                   truncation=True),
                               batched=True,
                               remove_columns=["Question", "Answer", "Context", "Source"])

tokenized_targets = rosa_dt.map(lambda x: tokenizer(x["Answer"],
                                                   truncation=True),
                               batched=True,
                               remove_columns=["Question", "Answer"])

input_lenghts = [len(x) for x in tokenized_inputs["input_ids"]]
max_source_length = int(np.percentile(input_lenghts, 100))
target_lenghts = [len(x) for x in tokenized_targets["input_ids"]]
max_target_length = int(np.percentile(target_lenghts, 95))
# Out:
# Map:   0%|          | 0/7560 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7560 [00:00<?, ? examples/s]

# %%
def preprocess_function(sample, padding="max_length"):
    # add prefix to the input for t5
    inputs = [f"Quesion: ## {q} ##\n Context: ## {c} ##" for q, c in zip(sample["Question"], sample["Context"])]
    # tokenize inputs
    model_inputs = tokenizer(inputs,
                             max_length=max_source_length,
                             padding=padding,
                             truncation=True)
    
    outputs = ["Answer: " + item for item in sample["Answer"]]
    # Tokenize targets with the `text_target` keyword argument
    labels = tokenizer(text_target=outputs,
                       max_length=max_target_length,
                       padding=padding,
                       truncation=True)
    # If we are padding here, replace all tokenizer.pad_token_id in the labels by -100 when we want to ignore
    # padding in the loss.
    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
        ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

rosa_tokenized_dataset = rosa_dt.map(preprocess_function,
                                     batched=True,
                                     remove_columns=["Question",
                                                     "Answer",
                                                     "id",
                                                     "Context",
                                                     "Source"])
print(f"Keys of tokenized dataset: {list(rosa_tokenized_dataset.features)}")
# Out:
# Map:   0%|          | 0/7560 [00:00<?, ? examples/s]
# Keys of tokenized dataset: ['input_ids', 'attention_mask', 'labels']

# %% [markdown]
# # Check model answers before fine tuning

# %%
def gen_answers(question, context=""):
    inp = f"Quesion: ## {question} ##\n Context: ## {context} ##"
    input_ids = tokenizer(inp, return_tensors="pt", truncation=True).input_ids.cuda()
    outputs = model.generate(input_ids=input_ids, max_new_tokens=1000, do_sample=True, top_p=1)
    answer = tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]
    return (question, answer)

# %%
questions = validation_df['Question'].tolist()
real_answers = validation_df['Answer'].tolist()
generated_answers = list()
for q in questions:
    question, answer = gen_answers(q)
    print(f"Question: {question}\n{'---'* 20}")
    print(f"Answer:\n{answer}\n\n")
# Out:
# Question: What is Red Hat OpenShift Service on AWS (ROSA)?
# ------------------------------------------------------------
# Answer:
# Red Hat OpenShift Service on AWS (ROSA) is Red Hat Software's cloud-native infrastructure platform to help organizations easily develop, run, and manage applications in the cloud.
#
#
# Question: Where can I go to get more information/details?
# ------------------------------------------------------------
# Answer:
# In order to access details about the location of the site, please access the official site and follow the links with your specific query about the article.
#
#
# Question: What are the benefits of Red Hat OpenShift Service on AWS (Key Features)?
# ------------------------------------------------------------
# Answer:
# OpenShift on AWS has partnered with AWS, enabling it to run Red Hat OpenShift software on AWS.
#
#
# Question: What are the differences between Red Hat OpenShift Service on AWS and Kubernetes?
# ------------------------------------------------------------
# Answer:
# Red Hat OpenShift Service on AWS Red Hat OpenShift Service on AWS allows developers to compose applications, deploy to containers, and administer services in a saas or eacm architecture by focusing on what's important to the business and IT: an easy-to-use developer-oriented platform, a complete orchestration ecosystem and an open, community-supported platform
#
#
# Question: What exactly am I responsible for and what is Red Hat / AWS responsible for?
# ------------------------------------------------------------
# Answer:
# This is a major change to what we have been able to leverage with our customers across the globe.
#
#
# Question: How does it work?
# ------------------------------------------------------------
# Answer:
# ## For a given m/s speed, all current (i.e. -m/s) for each elapsed time (M) are associated with the current (i.e. -c).
#
#
# Question: Where can I see a roadmap or make feature requests for the service?
# ------------------------------------------------------------
# Answer:
# Q: Who is the Product Manager of the service?
#
#
# Question: How is the pricing of Red Hat OpenShift Service on AWS calculated?
# ------------------------------------------------------------
# Answer:
# Using cloud provider's quoting and pricing service, OpenShift Service on AWS provides a quoting engine with real-time dynamic pricing that provides a transparent quoting and pricing process
#
#
# Question: When pricing out my EC2 instances, do I need to use RHEL for the operating system?
# ------------------------------------------------------------
# Answer:
# rbr> I am not going to do a Linux VM on an EC2 instance.
#
#
# Question: Does Red Hat OpenShift Service on AWS qualify for the AWS EDP Program?
# ------------------------------------------------------------
# Answer:
# Red Hat OpenShift Service on AWS aims to enable developers and systems integrators to build, deploy, and manage containers on Red Hat OpenShift Environments for Public Cloud.
#
#
# Question: Can I use spot/preemptible VMs?
# ------------------------------------------------------------
# Answer:
# Yes
#
#
# Question: Is there an upfront commitment?
# ------------------------------------------------------------
# Answer:
# Cancellation of the contract may only be done through written
#
#
# Question: How can I start using Red Hat OpenShift Service on AWS?
# ------------------------------------------------------------
# Answer:
# Use the OpenShift Online Console to download and install the Red Hat OpenShift Service image.
#
#
# Question: Do I need to sign/have a contract with Red Hat?
# ------------------------------------------------------------
# Answer:
# Quesion: What is the difference between paying for the software or Red Hat Support?
#
#
# Question: Is there a discount if I have unused OCP subscriptions?
# ------------------------------------------------------------
# Answer:
# YES. All unused OCP subscriptions (subscriptions that you do not want) expire after 3 months. After 3 months, OCP renewal rates will increase from $109 to $195 and OCP annual renewal license to $179.
#
#
# Question: Can I bring my own subscription to the service (e.g. Red Hat Cloud Access, OCP, IBM CloudPak)?
# ------------------------------------------------------------
# Answer:
# Please refer to this article for more information on buying and integrating XaaS with another provider.
#
#
# Question: Can I purchase middleware subscriptions on-demand for my ROSA clusters?
# ------------------------------------------------------------
# Answer:
# ## Are you interested in purchasing middleware subscriptions on-demand?
#
#
# Question: What are the regions where SREs have residency to operate?
# ------------------------------------------------------------
# Answer:
# ## SREs have residency to operate in their region.
#
#
# Question: Which AWS regions is the service available in?
# ------------------------------------------------------------
# Answer:
# AWS Regions:
#
#
# Question: Which compliance certifications does ROSA have so far?
# ------------------------------------------------------------
# Answer:
# ISO 75000 and ISO 17025 -
#
#
# Question: Can a cluster have worker nodes across multiple AWS regions?
# ------------------------------------------------------------
# Answer:
# AWS worker nodes are available in AWS Regions E1, E2, and G1.
#
#
# Question: What is the minimum number of worker nodes that a ROSA cluster can have?
# ------------------------------------------------------------
# Answer:
# RoSA (): The ROSA cluster has a minimum of two nodes: one master node (or ROSA daemon) and one worker node (or worker node).
#
#
# Question: Where can I find the product documentation for ROSA?
# ------------------------------------------------------------
# Answer:
# Where can I find the product documentation for ROSA?
#
#
# Question: Can an admin manage users and quotas?
# ------------------------------------------------------------
# Answer:
# Can I create a new user on my public folder?
#
#
# Question: When will features of the latest version of Kubernetes be supported in ROSA via OpenShift 4?
# ------------------------------------------------------------
# Answer:
# Rosa via OpenShift 6 was announced
#
#
# Question: How can customers get support for the service?
# ------------------------------------------------------------
# Answer:
# Customers can get support for the service for free by visiting the Support page.
#
#
# Question: What happens if I do not upgrade my cluster before the "end of life" date?
# ------------------------------------------------------------
# Answer:
# If your cluster is not upgraded after the "end of life" date, your cluster must be migrated to another cluster before the cluster shutdown.
#
#
# Question: What is the SLA?
# ------------------------------------------------------------
# Answer:
# SLA The single-point authentication (SLA) protocol of authentication is a protocol to authenticate users of the internet before they can access sensitive parts of web sites.
#
#
# Question: How will customers be notified when new features/updates are available?
# ------------------------------------------------------------
# Answer:
# ## ## Customers are notified when new features/updates are available
#
#
# Question: What version of OpenShift is running?
# ------------------------------------------------------------
# Answer:
# version>/version>
#
#
# Question: Is Open Service Broker for AWS (OBSA) supported?
# ------------------------------------------------------------
# Answer:
# (OBSA) is not currently supported by Amazon AWS
#
#
# Question: What is the underlying node OS used?
# ------------------------------------------------------------
# Answer:
# Underlying node OS There are various operating systems used in data centers and cloud operations:
#
#
# Question: What is the process for customers wishing to ‘offboard’ their deployment in ROSA - is there a process?
# ------------------------------------------------------------
# Answer:
# No. We work with customers to defer their migration to other cloud vendors, or are happy to provide this service if customers feel their current cloud vendor does not best suit their current needs.
#
#
# Question: What authentication mechanisms are supported with ROSA?
# ------------------------------------------------------------
# Answer:
# ROSA supports the following authentication mechanisms: Authentication Mechanisms ROSA supports three authentication mechanisms:
#
#
# Question: How will events such as product updates and scheduled maintenance be communicated?
# ------------------------------------------------------------
# Answer:
# Other products that are marketed by an OEM can directly compete with products that are produced or distributed by a private company.
#
#
# Question: Does ROSA have a hibernation or shut-down feature for any nodes in the cluster to save costs on infrastructure or to retain a configured cluster for long-term?
# ------------------------------------------------------------
# Answer:
# No, no.
#
#
# Question: Is SRE access to clusters secured by MFA?
# ------------------------------------------------------------
# Answer:
# ## The Secure Research Environment (SRE) is secured using multi-factor authentication (MFA)
#
#
# Question: What encryption keys, if any, are used in a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# ROSA uses an 8-bit AES-256 Key with 256-bit AES-256 key length (256-bit key size), using the MD5 hash of the ROSA root key for encryption.
#
#
# Question: If I specify a KMS key to use, what exactly gets encrypted with that key?
# ------------------------------------------------------------
# Answer:
# - The public key is used for the encryption of the asymmetric key
#
#
# Question: Is data on my cluster encrypted?
# ------------------------------------------------------------
# Answer:
# Quesion: Will my data on the cluster still be encrypted?
#
#
# Question: When can etcd encryption be done with a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# ROSA clusters are specifically adapted for purposes of encryption and privacy, and can run on non-critical and scalable systems.
#
#
# Question: How is etcd encryption configured in a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# ... etcd  etcd_key = crypto:0 for key/value pairs cipher_pass is 'public key : 'etcd_cc = 'odd: 0 'cccccccccc tcd_cnt:0 crypto = id:0, ccccccb:id cipher = 'id: 0' and cccccc2c = 0 for key, cipher = (crccle)'nf' and key, sec = ; for key, sec=
#
#
# Question: What infrastructure is provisioned as part of a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# ROSA (Resources on the Seas for Maritime Applications) is a cloud-native infrastructure designed for deployment on a premise or under a public cloud.
#
#
# Question: I see there are two "kinds" of ROSA clusters. One uses an IAM user with admin permissions and the other AWS STS. Which should I choose?
# ------------------------------------------------------------
# Answer:
# Answer: (Option A)
#
#
# Question: I’m seeing a number of permission or failure errors related to prerequisite tasks or cluster creation, what might be the problem?
# ------------------------------------------------------------
# Answer:
# What does Precious Mean (Light) mean in Windows PowerShell?
#
#
# Question: What are the available storage options?
# ------------------------------------------------------------
# Answer:
# ##The system can use a diskette medium for storing programs and data and can also use Flash drives for storing files that include program files.
#
#
# Question: What options are available to use shared storage in containers?
# ------------------------------------------------------------
# Answer:
# Shared storage may be as a global or a local.
#
#
# Question: Can I deploy into an already existing VPC and choose the specific subnets?
# ------------------------------------------------------------
# Answer:
# Can I deploy to an already existing VPC and choose the specific subnets?
#
#
# Question: Which network plugin is used in Red Hat OpenShift Service on AWS?
# ------------------------------------------------------------
# Answer:
# Red Hat OpenShift Service on AWS uses the GRE network plugin
#
#
# Question: Is cross-namespace networking supported?
# ------------------------------------------------------------
# Answer:
# X.509 supports only addressing, but does not support namespace, nor is it able to do host-to-host addresses.
#
#
# Question: Can more than one ROSA cluster be set up in one VPC?
# ------------------------------------------------------------
# Answer:
# More than one ROSA cluster can be set up in a single VPC.
#
#
# Question: Can I use Prometheus/Grafana to monitor containers and manage capacity?
# ------------------------------------------------------------
# Answer:
# Yes, you can use Prometheus/Grafana to monitor containers/racks and control space
#
#
# Question: Can I see audit logs output from the cluster control-plane?
# ------------------------------------------------------------
# Answer:
# Specify your cluster's security configuration for the audit logs.
#
#
# Question: Can I use an AWS Permissions Boundary around the policies for my cluster?
# ------------------------------------------------------------
# Answer:
# Yes
#
#
# Question: Do ROSA worker nodes share the same AMI as other OpenShift products?
# ------------------------------------------------------------
# Answer:
# ROSA is available as an AMI that only contains OpenShift Server software and Docker container images.
#
#
# Question: Are backups taken for clusters?
# ------------------------------------------------------------
# Answer:
# a) Storage — Disk, tape, or magnetic media â€“ Encrypted data â€“ Strict restrictions â€“ Data â€“ Disk encryption â€“ Encrypted data â€“ Data â€“ Encrypted data encryption â€“ Maximum data encryption â€“ Data encryption is not encrypted with the key that was created when the data was created in the first place.
#
#
# Question: Is ROSA GDPR Compliant?
# ------------------------------------------------------------
# Answer:
# ## ROSA is fully compliant with the GDPR regulations.
#
#
# Question: Does the ROSA CLI accept Multi-region KMS keys for EBS encryption?
# ------------------------------------------------------------
# Answer:
# ROSA CLI supports multi-region KMS keys.
#
#
# Question: Can I define a custom domain and certificate for my applications?
# ------------------------------------------------------------
# Answer:
# Ok, can I set an own domain?
#
#
# Question: How are the ROSA domain certificates managed?
# ------------------------------------------------------------
# Answer:
# RCC is implemented via an atomic method with certs consisting of a hash key that identifies an egressor domain certificate, and which can be reloaded by the administrator.
#
#
# Question: What features are upcoming for ROSA?
# ------------------------------------------------------------
# Answer:
# ROSA 5's upcoming features include a third syncing mode to allow ROSA to keep track of separate storage and memory on multiple logical drives, a new UI for ROSA 6, as well as the ability to download to any external drive or local hard drive.
#
#
# Question: What kind of instances are supported for worker nodes?
# ------------------------------------------------------------
# Answer:
# A worker node type is a multi-instance of the node type.
#
#
# Question: Does ROSA support an air-gapped, disconnected environment where the ROSA cluster does not have internet access?
# ------------------------------------------------------------
# Answer:
# ROSA supports air-gapped, disconnected environments where the ROSA cluster does not have internet access.
#
#
# Question: Is node autoscaling available?
# ------------------------------------------------------------
# Answer:
# For instance, if a user wants to do dynamic scaling of an application, using a new node is an acceptable option.
#
#
# Question: What is the maximum number of worker nodes that a cluster can support?
# ------------------------------------------------------------
# Answer:
# Worker nodes are distributed on the underlying hardware network. A worker node can be a single-processor node, a multi-processor node, or a shared memory node.

# %% [markdown]
# # Training
# ## Prepare model for training
# Some pre-processing needs to be done before training such an int8 model using `peft`, therefore let's import an utiliy function `prepare_model_for_int8_training` that will:
# - Casts all the non `int8` modules to full precision (`fp32`) for stability
# - Add a `forward_hook` to the input embedding layer to enable gradient computation of the input hidden states
# - Enable gradient checkpointing for more memory-efficient training

# %%
# Define LoRA Config (default parameters)
lora_config = LoraConfig(
 r=16,
 lora_alpha=32,
 target_modules=["q", "v"],
 lora_dropout=0.05,
 bias="none",
 task_type=TaskType.SEQ_2_SEQ_LM
)
# prepare int-8 model for training
model = prepare_model_for_int8_training(model)

# add LoRA adaptor
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# we want to ignore tokenizer pad token in the loss
label_pad_token_id = -100

# Data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=8
)

output_dir="lora-flan-t5-xl"

# Define training args
training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
	auto_find_batch_size=True,
    learning_rate=1e-3, # The learning rate for the neural network
    num_train_epochs=5,
    logging_dir=f"{output_dir}/logs",
    logging_strategy="steps",
    logging_steps=500,
    save_strategy="epoch",
    save_total_limit=1,
    report_to="tensorboard",
)

# Create Trainer instance
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=rosa_tokenized_dataset,
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
# Out:
# trainable params: 9437184 || all params: 2859194368 || trainable%: 0.33006444422319176

# %%
# train model
trainer.train()
# Out:
# /opt/app-root/lib64/python3.9/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/app-root/lib64/python3.9/site-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='4725' max='4725' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4725/4725 3:27:41, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.948100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.831100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.745300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.697600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.622800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.600600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.546800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.505900</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.469400</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/app-root/lib64/python3.9/site-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /opt/app-root/lib64/python3.9/site-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /opt/app-root/lib64/python3.9/site-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# TrainOutput(global_step=4725, training_loss=0.6541617434869998, metrics={'train_runtime': 12464.4148, 'train_samples_per_second': 3.033, 'train_steps_per_second': 0.379, 'total_flos': 4.56150095364096e+16, 'train_loss': 0.6541617434869998, 'epoch': 5.0})

# %%
trainer.save_model('../models/rosa-flan-2')

# %% [markdown]
# # Validation

# %%
# Helper function for generating answers
def gen_answers(question, context=""):
    inp = f"Quesion: ## {question} ##\n Context: ## {context} ##"
    input_ids = tokenizer(inp, return_tensors="pt", truncation=True).input_ids.cuda()
    outputs = model.generate(input_ids=input_ids, max_new_tokens=1000, do_sample=True, top_p=1)
    answer = tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]
    return (question, answer)

# %% [markdown]
# ## Without context
# In this section, the input to the model is just the question without any context.

# %%
# Load peft config for pre-trained checkpoint etc.
peft_model_id = "../../../models/rosa-flan-2"
config = PeftConfig.from_pretrained(peft_model_id)

# load base LLM model and tokenizer
model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path,  load_in_8bit=True,  device_map={"":0})
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id, device_map={"":0})
model.eval()

print("Peft model loaded")

# %%
questions = validation_df['Question'].tolist()
real_answers = validation_df['Answer'].tolist()
generated_answers = list()
for q in questions:
    question, answer = gen_answers(q)
    print(f"Question: {question}\n{'---'* 20}")
    print(f"Answer:\n{answer}\n\n")
# Out:
# Question: What is Red Hat OpenShift Service on AWS (ROSA)?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS (ROSA) is a managed service that provides a managed cloud platform and service oriented approach to container application deployment on the Amazon Web Services (AWS) platform. ROSA provides a secure and reliable environment for container applications running on the Amazon Web Services (AWS) cloud platform.
#
#
# Question: Where can I go to get more information/details?
# ------------------------------------------------------------
# Answer:
# Answer: To get more information/details, you can go to the wikiHow site.
#
#
# Question: What are the benefits of Red Hat OpenShift Service on AWS (Key Features)?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS offers a secure, scalable, and reliable environment for running applications on OpenShift. Its features include enhanced security, enhanced automation, increased scalability, and reduced cost.
#
#
# Question: What are the differences between Red Hat OpenShift Service on AWS and Kubernetes?
# ------------------------------------------------------------
# Answer:
# Answer: You can use Red Hat OpenShift Service on AWS to manage and deploy containerized applications, while using Kubernetes to manage and deploy containerized applications.
#
#
# Question: What exactly am I responsible for and what is Red Hat / AWS responsible for?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat / AWS is responsible for providing the infrastructure required to run applications, scale services, and manage applications, and is also responsible for monitoring the applications and services to ensure that they are running optimally. Additionally, AWS provides a set of tools and services to help manage the applications and services. Additionally, AWS is also responsible for providing the infrastructure necessary to run the applications and services.
#
#
# Question: How does it work?
# ------------------------------------------------------------
# Answer:
# Answer: To work, it works by allowing the user to choose from a set of commands that match their specified criteria. These commands include commands used to create, update, modify, and delete records, images, and other items. Once the command is selected, the user can then select the desired data to be deleted by selecting the appropriate 'Batch' command from the drop-down menu. The function then completes the specified action by removing the selected items.
#
#
# Question: Where can I see a roadmap or make feature requests for the service?
# ------------------------------------------------------------
# Answer:
# Answer: To view a roadmap and make feature requests for the service, go to the Red Hat product website.
#
#
# Question: How is the pricing of Red Hat OpenShift Service on AWS calculated?
# ------------------------------------------------------------
# Answer:
# Answer: The pricing of Red Hat OpenShift Service on AWS is calculated based on the number of consumed instances, number of processor cores, and the amount of memory.
#
#
# Question: When pricing out my EC2 instances, do I need to use RHEL for the operating system?
# ------------------------------------------------------------
# Answer:
# Answer: When pricing out your EC2 instances, it is recommended that they be running on RHEL.
#
#
# Question: Does Red Hat OpenShift Service on AWS qualify for the AWS EDP Program?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS qualifies for the AWS EDP Program by meeting the AWS Service Requirements for Eligibility requirements.
#
#
# Question: Can I use spot/preemptible VMs?
# ------------------------------------------------------------
# Answer:
# Answer: Spot/Preemptible VMs can be used in a Kubernetes cluster, if the cluster possesses enough capacity for space and processing power. However, the instances should be patched with preemptible VMs, which can be wiped for maintenance and repopulated using the VMs for UI loads.
#
#
# Question: Is there an upfront commitment?
# ------------------------------------------------------------
# Answer:
# Answer: There is a minimum one-year commitment.
#
#
# Question: How can I start using Red Hat OpenShift Service on AWS?
# ------------------------------------------------------------
# Answer:
# Answer: To start using Red Hat OpenShift Service on AWS, you need to create a free Red Hat account, enter your email address in the "Sign Up" section, enter a valid credit card in the "Create Account" section, and then follow the instructions in the "Share" section. Once you have completed these steps, you can
#
#
# Question: Do I need to sign/have a contract with Red Hat?
# ------------------------------------------------------------
# Answer:
# Answer: You need to sign a contract with Red Hat before you can use their products.
#
#
# Question: Is there a discount if I have unused OCP subscriptions?
# ------------------------------------------------------------
# Answer:
# Answer: If you have unused OCP subscriptions, you can get a 25% discount on your subscription renewal.
#
#
# Question: Can I bring my own subscription to the service (e.g. Red Hat Cloud Access, OCP, IBM CloudPak)?
# ------------------------------------------------------------
# Answer:
# Answer: You can bring your own subscription to the service (e.g. Red Hat Cloud Access, OCP, IBM CloudPak) if you are eligible, and then pay the subscription fee.
#
#
# Question: Can I purchase middleware subscriptions on-demand for my ROSA clusters?
# ------------------------------------------------------------
# Answer:
# Answer: Yes, on-demand middleware subscriptions are available for ROSA clusters. They allow for the deployment of a set of APIs without any downtime.
#
#
# Question: What are the regions where SREs have residency to operate?
# ------------------------------------------------------------
# Answer:
# Answer: SREs have residency to operate in the following regions: Americas (North America, Europe, Asia Pacific), Asia (East Asia, Australasia, & Middle East), Africa (Serbia, Ghana, Sierra Leone), and Latin America (Santa Fe).
#
#
# Question: Which AWS regions is the service available in?
# ------------------------------------------------------------
# Answer:
# Answer: The service is available in the Americas, Europe, Northern Hemisphere, South East, and South West regions.
#
#
# Question: Which compliance certifications does ROSA have so far?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA has been certified to be IAM-accredited for three years (2013, 2014, 2015) and ISO27001:2005 Certified for Information Security.
#
#
# Question: Can a cluster have worker nodes across multiple AWS regions?
# ------------------------------------------------------------
# Answer:
# Answer: cluster can have worker nodes across multiple AWS regions, but they can only be registered in one AWS region.
#
#
# Question: What is the minimum number of worker nodes that a ROSA cluster can have?
# ------------------------------------------------------------
# Answer:
# Answer: The minimum number of worker nodes that a ROSA cluster can have is four.
#
#
# Question: Where can I find the product documentation for ROSA?
# ------------------------------------------------------------
# Answer:
# Answer: The product documentation for ROSA can be found at https://help.redhat.com/rosa/html>.
#
#
# Question: Can an admin manage users and quotas?
# ------------------------------------------------------------
# Answer:
# Answer: an admin can manage users and quotas, but cannot create new users and quotas.
#
#
# Question: When will features of the latest version of Kubernetes be supported in ROSA via OpenShift 4?
# ------------------------------------------------------------
# Answer:
# Answer: Features of the latest version of Kubernetes will be supported in ROSA via OpenShift 2 by 2020.
#
#
# Question: How can customers get support for the service?
# ------------------------------------------------------------
# Answer:
# Answer: Customers can contact Red Hat Customer Support at https://support.redhat.com/> for information regarding the service or to request a quotation.
#
#
# Question: What happens if I do not upgrade my cluster before the "end of life" date?
# ------------------------------------------------------------
# Answer:
# Answer: If you do not upgrade your cluster before the "end of life" date, the cluster will be decommissioned and removed from the registry.
#
#
# Question: What is the SLA?
# ------------------------------------------------------------
# Answer:
# Answer: The Service Level Agreement (SLA) is a contract that defines the terms and conditions under which an organization can use the technology.
#
#
# Question: How will customers be notified when new features/updates are available?
# ------------------------------------------------------------
# Answer:
# Answer: Customers will be notified when new features/updates are available via email and/or notifications on their mobile devices.
#
#
# Question: What version of OpenShift is running?
# ------------------------------------------------------------
# Answer:
# Answer: OpenShift is running on the openShift 6.7 version.
#
#
# Question: Is Open Service Broker for AWS (OBSA) supported?
# ------------------------------------------------------------
# Answer:
# Answer: Open Service Broker for AWS (OBSA) is supported by Istio.
#
#
# Question: What is the underlying node OS used?
# ------------------------------------------------------------
# Answer:
# Answer: The underlying node OS used is Kubernetes.
#
#
# Question: What is the process for customers wishing to ‘offboard’ their deployment in ROSA - is there a process?
# ------------------------------------------------------------
# Answer:
# Answer: The customer must initiate the "offboard" process by sending a brief message to the customer support team. The customer can then log into their ROSA account and navigate to the "Deployments" page where they can select the deployment they wish to take offboarding. The customer is then able to select the "Offboard" link and follow the steps to complete the offload process.
#
#
# Question: What authentication mechanisms are supported with ROSA?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA supports OpenID Connect, Auth0rnation on the web, and OAuth for mobile users.
#
#
# Question: How will events such as product updates and scheduled maintenance be communicated?
# ------------------------------------------------------------
# Answer:
# Answer: Events such as product updates and scheduled maintenance will be communicated via newsletters or newsletter_posts.
#
#
# Question: Does ROSA have a hibernation or shut-down feature for any nodes in the cluster to save costs on infrastructure or to retain a configured cluster for long-term?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA has no means to shutdown any nodes in the cluster to save costs on infrastructure or to retain a configured cluster for long-term.
#
#
# Question: Is SRE access to clusters secured by MFA?
# ------------------------------------------------------------
# Answer:
# Answer: SRE access to clusters is secured by multi-factor authentication (MFA) using SRE tokens.
#
#
# Question: What encryption keys, if any, are used in a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: The encryption keys used in a new ROSA cluster are always the same as used in an existing cluster.
#
#
# Question: If I specify a KMS key to use, what exactly gets encrypted with that key?
# ------------------------------------------------------------
# Answer:
# Answer: The data that is encrypted with the KMS key is the data that is used to decrypt the request.
#
#
# Question: Is data on my cluster encrypted?
# ------------------------------------------------------------
# Answer:
# Answer: Data on your cluster is usually encrypted in one of two ways: a password is used to authenticate requests, and another key is used to store the data.
#
#
# Question: When can etcd encryption be done with a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: cetcd encryption can be done with a ROSA cluster as soon as a ROSA cluster is created, but typically at the end of the installation process.
#
#
# Question: How is etcd encryption configured in a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer:etcd encryption is configured in a ROSA cluster by setting default encryption policy for each service node. The process also defines the encryption key and key parameters, such as the bandwidth, encryption key strength, and length of time encryption keys are valid.
#
#
# Question: What infrastructure is provisioned as part of a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA cluster provides a base cluster with machine instances, virtual machines, and networking resources, as well as other infrastructure resources such as storage, database, and networking hardware.
#
#
# Question: I see there are two "kinds" of ROSA clusters. One uses an IAM user with admin permissions and the other AWS STS. Which should I choose?
# ------------------------------------------------------------
# Answer:
# Answer: Choose the AWS STS method if you are running on an OpenShift cluster. Logging in the admin mode for cluster resources is required for the ROSA approach.
#
#
# Question: I’m seeing a number of permission or failure errors related to prerequisite tasks or cluster creation, what might be the problem?
# ------------------------------------------------------------
# Answer:
# Answer: The problem might be that the user is denied permission or that the access is restricted to certain conditions.

# %% [markdown]
# ## Validation with context from embeddings

# %%
# Get all documents and split them into chunks
loader = DirectoryLoader('../../../data/external', glob="**/*.md", loader_cls=TextLoader)
documents = loader.load()
text_splitter = MarkdownTextSplitter(chunk_overlap=0, chunk_size=750)
texts = text_splitter.split_documents(documents)
print(f"{len(documents)} documents were loaded in {len(texts)} chunks")
# Out:
# 75 documents were loaded in 7153 chunks

# %% [markdown]
# Now we create (or load, if it already exists) a vector store from the documents:

# %%
# Convert chunks to vectors and store them in a database
embeddings = HuggingFaceEmbeddings()
db_dir = "../../../data/interim"
docsearch = None
if os.path.isdir(os.path.join(db_dir, "index/rosa-t5")):
    # Load the existing vector store
    docsearch = Chroma(persist_directory=db_dir, embedding_function=embeddings)
else:
    # Create a new vector store
    docsearch = Chroma.from_documents(texts, embeddings, persist_directory=db_dir)
    docsearch.persist()
# Out:
# Unable to connect optimized C data functions [No module named '_testbuffer'], falling back to pure Python

# %%
questions = validation_df['Question'].tolist()
real_answers = validation_df['Answer'].tolist()
contexts = [docsearch.similarity_search(q, 1)[0].page_content for q in questions]
generated_answers = list()
for q, c in zip(questions, contexts):
    question, answer = gen_answers(q, c)
    print(f"Question: {question}\n{'---'* 20}")
    print(f"Answer:\n{answer}\n\n")
# Out:
# Question: What is Red Hat OpenShift Service on AWS (ROSA)?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS (ROSA) is a fully-managed turnkey application platform that allows you to focus on what matters most, delivering value to your customers by building and deploying applications. Red Hat SRE experts manage the underlying platform so you don’t have to worry about the complexity of infrastructure management.
#
#
# Question: Where can I go to get more information/details?
# ------------------------------------------------------------
# Answer:
# Answer: You can look at the Red Hat OpenShift Cluster Guide on GitHub for more information and a reference page to the OpenShift APIs.
#
#
# Question: What are the benefits of Red Hat OpenShift Service on AWS (Key Features)?
# ------------------------------------------------------------
# Answer:
# Answer: The benefits of Red Hat OpenShift Service on AWS include access and use of Red Hat OpenShift on demand with a self-service on-boarding experience through the AWS management console. This includes flexible pricing with an on-demand hourly or annual billing model. Customers will receive a single bill from AWS for both Red Hat OpenShift and AWS consumption. Additionally, installation, management, maintenance, and upgrades are performed by Red Hat site reliability engineers (SRE) with joint Red Hat and Amazon support and a 99.95% SLA.
#
#
# Question: What are the differences between Red Hat OpenShift Service on AWS and Kubernetes?
# ------------------------------------------------------------
# Answer:
# Answer: The differences between Red Hat OpenShift Service on AWS and Kubernetes include container management, automation (Operators), networking, load balancing, service mesh, CI/CD, firewall, monitoring, registry, authentication, and authorization capabilities.
#
#
# Question: What exactly am I responsible for and what is Red Hat / AWS responsible for?
# ------------------------------------------------------------
# Answer:
# Answer: The customer is responsible for the applications, workloads, and data that they deploy to Red Hat OpenShift Service on AWS. Red Hat provides various tools to help the customer manage data and applications on the platform.
#
#
# Question: How does it work?
# ------------------------------------------------------------
# Answer:
# Answer: The backing channel acts as a proxy that copies its subscriptions to the user-created channel object, and sets the user-created channel object status to reflect the status of the backing channel.
#
#
# Question: Where can I see a roadmap or make feature requests for the service?
# ------------------------------------------------------------
# Answer:
# Answer: The Generally Available and Technology Preview features tracker is a place where you can view a roadmap for the service and make feature requests.
#
#
# Question: How is the pricing of Red Hat OpenShift Service on AWS calculated?
# ------------------------------------------------------------
# Answer:
# Answer: The pricing of Red Hat OpenShift Service on AWS is calculated by adding the components of the service roles, instances, and services. The ROSA Pricing page gives more information about these components, including details on the pricing structure and associated charges.
#
#
# Question: When pricing out my EC2 instances, do I need to use RHEL for the operating system?
# ------------------------------------------------------------
# Answer:
# Answer: No, because ROSA includes Red Hat Enterprise Linux CoreOS (RHCOS) as the operating system, you only need to choose Linux. ROSA cluster creation handles the setup of all the RHCOS nodes entirely.
#
#
# Question: Does Red Hat OpenShift Service on AWS qualify for the AWS EDP Program?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS fully qualifies for 100% of the spend on the AWS Enterprise Discount Program.
#
#
# Question: Can I use spot/preemptible VMs?
# ------------------------------------------------------------
# Answer:
# Answer: You can use spot/preemptible VMs for workloads that can tolerate interruptions, but it is important to understand that these VMs might be interrupted at any time. You cannot disable the option after the machine pool is created.
#
#
# Question: Is there an upfront commitment?
# ------------------------------------------------------------
# Answer:
# Answer: There is no required upfront commitment. ROSA clusters can be provisioned on-demand, with pay-as-you-go billing, for both AWS & OpenShift expenses.
#
#
# Question: How can I start using Red Hat OpenShift Service on AWS?
# ------------------------------------------------------------
# Answer:
# Answer: To start using Red Hat OpenShift Service on AWS, you must possess an active Red Hat OpenShift Service on AWS subscription on your Red Hat account and install the version of the Red Hat OpenShift Client Tool (the oc client tool) that matches your Red Hat OpenShift Service on AWS version and add it to your path.
#
#
# Question: Do I need to sign/have a contract with Red Hat?
# ------------------------------------------------------------
# Answer:
# Answer: ccording to Appendix 4 of the Red Hat Enterprise Agreement (Agenda 4 for Online Subscription Services) you need to accept the terms and conditions of the agreement.
#
#
# Question: Is there a discount if I have unused OCP subscriptions?
# ------------------------------------------------------------
# Answer:
# Answer: No, unused OCP subscriptions can be used to count as a resource in a second account.
#
#
# Question: Can I bring my own subscription to the service (e.g. Red Hat Cloud Access, OCP, IBM CloudPak)?
# ------------------------------------------------------------
# Answer:
# Answer: You can bring your own subscription to the service (e.g. Red Hat Cloud Access, OCP, IBM CloudPak), but it must meet the service definition requirements.
#
#
# Question: Can I purchase middleware subscriptions on-demand for my ROSA clusters?
# ------------------------------------------------------------
# Answer:
# Answer: There is currently no on-demand purchasing ability for your ROSA clusters.
#
#
# Question: What are the regions where SREs have residency to operate?
# ------------------------------------------------------------
# Answer:
# Answer: SREs have residency to operate in the following regions: India, the United States, and China.
#
#
# Question: Which AWS regions is the service available in?
# ------------------------------------------------------------
# Answer:
# Answer: The service is available in eu-west-2 (London) - eu-west-3 (Paris) - me-south-1 (Bahrain, AWS opt-in required) - sa-east-1 (So Paulo) - us-east-1 (N. Virginia) - us-east-2 (Ohio) - us-west-1 (N. California) - us-west-2 (Oregon)
#
#
# Question: Which compliance certifications does ROSA have so far?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA has ISO 27001:2005 certifications and is certified to PCI-DSS Level 3, ISO 4096:2008, and ISO 27001:2010.
#
#
# Question: Can a cluster have worker nodes across multiple AWS regions?
# ------------------------------------------------------------
# Answer:
# Answer: cluster can have worker nodes across multiple AWS regions if the associated regions have at least 3 availability zones.
#
#
# Question: What is the minimum number of worker nodes that a ROSA cluster can have?
# ------------------------------------------------------------
# Answer:
# Answer: The minimum number of worker nodes that a ROSA cluster can have is 10.
#
#
# Question: Where can I find the product documentation for ROSA?
# ------------------------------------------------------------
# Answer:
# Answer: The product documentation for ROSA can be found at https://docs.redhat.com/openshift/rosa].
#
#
# Question: Can an admin manage users and quotas?
# ------------------------------------------------------------
# Answer:
# Answer: mdi amdi can manage users and quotas in addition to accessing all user created projects.
#
#
# Question: When will features of the latest version of Kubernetes be supported in ROSA via OpenShift 4?
# ------------------------------------------------------------
# Answer:
# Answer: Features of the latest version of Kubernetes will be supported in ROSA via OpenShift 4 as the OpenShift platform evolves.
#
#
# Question: How can customers get support for the service?
# ------------------------------------------------------------
# Answer:
# Answer: Customers can get support for the service by making a request in the HelpDesk.
#
#
# Question: What happens if I do not upgrade my cluster before the "end of life" date?
# ------------------------------------------------------------
# Answer:
# Answer: If you do not upgrade the cluster before the "end of life" date, the cluster will transition to a Limited Support status until it is upgraded to a supported version. Red Hat provides commercially reasonable support to upgrade from an unsupported version to a supported version, however, if a supported upgrade path is no longer available, you might have to create a new cluster and migrate your workloads.
#
#
# Question: What is the SLA?
# ------------------------------------------------------------
# Answer:
# Answer: The Secure Logging Answer: The Secure Logging (SLA) is a set of rules that provide a minimum level of security for your data in a Kubernetes cluster. It establishes the minimum requirements for using the cluster, such as limiting access to certain resources and ensuring that data is secure.
#
#
# Question: How will customers be notified when new features/updates are available?
# ------------------------------------------------------------
# Answer:
# Answer: Customers will be notified when new features/updates are available by receiving email notifications or by checking the ‘Updates’ section of the web console.
#
#
# Question: What version of OpenShift is running?
# ------------------------------------------------------------
# Answer:
# Answer: The version field specifies the version of OpenShift to install and defaults to the latest available version.
#
#
# Question: Is Open Service Broker for AWS (OBSA) supported?
# ------------------------------------------------------------
# Answer:
# Answer: Open Service Broker for AWS (OBSA) is supported by Red Hat, which requires the user to have an OCM account and be issued an IAM role.
#
#
# Question: What is the underlying node OS used?
# ------------------------------------------------------------
# Answer:
# Answer: The underlying node OS used is Red Hat CoreOS.
#
#
# Question: What is the process for customers wishing to ‘offboard’ their deployment in ROSA - is there a process?
# ------------------------------------------------------------
# Answer:
# Answer: Customers wishing to 'offboard' their deployment in ROSA must first disable the service in the ASEA config file as a new OU, and then deploy the ROSA service in the dedicated member account.
#
#
# Question: What authentication mechanisms are supported with ROSA?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA supports several commercially available IDPs and common protocols, including OpenID Connect, oAuth, the OpenShift Logging API, and the OpenID Connect (OIDC) API. The full listing can be found in the ROSA documentation.
#
#
# Question: How will events such as product updates and scheduled maintenance be communicated?
# ------------------------------------------------------------
# Answer:
# Answer: Events such as product updates and scheduled maintenance will be communicated through the use of announcements, notifications, and alerts.
#
#
# Question: Does ROSA have a hibernation or shut-down feature for any nodes in the cluster to save costs on infrastructure or to retain a configured cluster for long-term?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA doesn't have a hibernation or shut-down feature for any nodes in the cluster to save costs on infrastructure or to retain a configured cluster for long-term.
#
#
# Question: Is SRE access to clusters secured by MFA?
# ------------------------------------------------------------
# Answer:
# Answer: SRE access to clusters is secured by MFA. See [SRE access](https://docs.openshift.com/rosa/rosa_architecture/rosa_policy_service_definition/rosa-policy-process-security.html#rosa-policy-sre-access_rosa-policy-process-security) in the documentation for more information.
#
#
# Question: What encryption keys, if any, are used in a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: We encrypt EBS volumes that we use for ROSA, using a key stored in KMS. Customers have the option to provide their own KMS keys at cluster creation time as well. If you specify a KMS key, only temporary ESB volumes are encrypted with that key.
#
#
# Question: If I specify a KMS key to use, what exactly gets encrypted with that key?
# ------------------------------------------------------------
# Answer:
# Answer: When you specify a KMS key to use, the workload is encrypted with that key.
#
#
# Question: Is data on my cluster encrypted?
# ------------------------------------------------------------
# Answer:
# Answer: Data on your cluster is encrypted according to the data retention policy.
#
#
# Question: When can etcd encryption be done with a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: Etcd encryption can be enabled with a ROSA cluster at cluster creation time. This incurs additional overhead with negligible security risk mitigation, see the prior question about EBS encryption.
#
#
# Question: How is etcd encryption configured in a ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: Etcd encryption is configured in a ROSA cluster the same as in OCP. The aescbc cypher is used and the setting is patched during cluster deployment. For further details see [etcd encryption](https://docs.openshift.com/rosa/rosa_policy/rosa-service-definition.html#rosa-sdpolicy-etcd-
#
#
# Question: What infrastructure is provisioned as part of a new ROSA cluster?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA cluster is provisioned with a public network, but Red Hat manages the cluster with limited access through a public network. Alternatively, install a cluster using AWS PrivateLink, which is hosted on private subnets only.
#
#
# Question: I see there are two "kinds" of ROSA clusters. One uses an IAM user with admin permissions and the other AWS STS. Which should I choose?
# ------------------------------------------------------------
# Answer:
# Answer: You should choose AWS STS. These aren't "kinds" but rather credential methods that basically "how do you grant Red Hat the permissions needed in order to perform the required actions in your AWS account?". The roadmap forward is focused on STS, and the IAM user method will eventually be deprecated. This better aligns with principles of least privilege and is much better aligned to secure practices in cloud service resource management. Please see the section [ROSA with STS Explained](/rosa/15-sts_explained) for a detailed explanation.
#
#
# Question: I’m seeing a number of permission or failure errors related to prerequisite tasks or cluster creation, what might be the problem?
# ------------------------------------------------------------
# Answer:
# Answer: tional tasks or cluster creation errors may be the problem. The cluster could be accidentally deleted, the workload is too heavy, or the cluster configuration is incorrect. Contact Red Hat Support for more information.
#
#
# Question: What are the available storage options?
# ------------------------------------------------------------
# Answer:
# Answer: The available storage options are - iscsi, nfs, persistentVolumeClaim, photonPersistentDisk, portworxVolume, projected, quobyte, rbd, and scaleIO.
#
#
# Question: What options are available to use shared storage in containers?
# ------------------------------------------------------------
# Answer:
# Answer: Containers can use the alloc, vmic, magic, everything, default, or include storage options to use shared storage.
#
#
# Question: Can I deploy into an already existing VPC and choose the specific subnets?
# ------------------------------------------------------------
# Answer:
# Answer: No. At install time you are able to select whether you would like to deploy to an existing VPC and then choose that VPC. You will then be able to select the desired subnets and also provide a valid CIDR range (encompassing the subnets) that the installer will handle using those subnets. Please see the VPC section in the [vpc](https://docs.openshift.com/rosa/rosa_
#
#
# Question: Which network plugin is used in Red Hat OpenShift Service on AWS?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS uses the OpenShift-SDN - OVN-Kubernetes networking plugin.
#
#
# Question: Is cross-namespace networking supported?
# ------------------------------------------------------------
# Answer:
# Answer: Cross-namespace networking is not supported by default.
#
#
# Question: Can more than one ROSA cluster be set up in one VPC?
# ------------------------------------------------------------
# Answer:
# Answer: lthough the instructions use the AWS CLI to create the necessary networking to deploy a Private Link ROSA cluster into a Single AZ, it cannot be deployed to different availability zones simultaneously. The only option is for a subnet to be created to an availability zone with the same instance type.
#
#
# Question: Can I use Prometheus/Grafana to monitor containers and manage capacity?
# ------------------------------------------------------------
# Answer:
# Answer: Prometheus/Grafana can be used to monitor containers and manage capacity by adding /targets to the end of the URL to see the list of available targets. It can also be used to send alerts of any issues to the Prometheus UI.
#
#
# Question: Can I see audit logs output from the cluster control-plane?
# ------------------------------------------------------------
# Answer:
# Answer: udit logs output from the cluster control-plane can be viewed in the AWS Console.
#
#
# Question: Can I use an AWS Permissions Boundary around the policies for my cluster?
# ------------------------------------------------------------
# Answer:
# Answer: Yes, using AWS Permissions Boundary is supported.
#
#
# Question: Do ROSA worker nodes share the same AMI as other OpenShift products?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA worker nodes use a different AMI from OSD and OCP. Control Plane and Infra node AMIs are common across products in the same version.
#
#
# Question: Are backups taken for clusters?
# ------------------------------------------------------------
# Answer:
# Answer: Backups are taken for clusters in most cases.
#
#
# Question: Is ROSA GDPR Compliant?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA is GDPR Compliant: https://www.redhat.com/en/gdpr is a link to the Red Hat documentation about GDPR compliance.
#
#
# Question: Does the ROSA CLI accept Multi-region KMS keys for EBS encryption?
# ------------------------------------------------------------
# Answer:
# Answer: The ROSA CLI does not enable Multi-region KMS keys for EBS encryption.
#
#
# Question: Can I define a custom domain and certificate for my applications?
# ------------------------------------------------------------
# Answer:
# Answer: You can define a custom domain and certificate for your applications by configuring the Certificate Authorities (CAs) and Certificate Signing Requests (CSRs) associated with the domain.
#
#
# Question: How are the ROSA domain certificates managed?
# ------------------------------------------------------------
# Answer:
# Answer: The ROSA domain certificates are managed by Red Hat infrastructure (Hive).
#
#
# Question: What features are upcoming for ROSA?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA is upcoming with support for the Istio CR, a new AI-enabled service that provides insights into customer relationships, and improved integration with the AWS CloudWatch metrics and alerting services.
#
#
# Question: What kind of instances are supported for worker nodes?
# ------------------------------------------------------------
# Answer:
# Answer: Red Hat OpenShift Service on AWS offers the following worker node instance types and sizes: m5.xlarge (4 vCPU, 16 GiB) - m5.2xlarge (8 vCPU, 32 GiB) - m5.4xlarge (16 vCPU, 64 GiB) - m5.8xlarge (32 vCPU, 128 GiB) - m5.12xlarge (48 vCPU, 192 GiB) - m5.16xlarge (64 vCPU, 256 GiB) - m5.24xlarge (96 vCPU, 384 GiB) - m5a.xlarge (4 vCPU, 16 GiB) - m5a.2xlarge (8 vCPU, 32 GiB) - m5a.4xlarge (16 vCPU, 64 GiB) - m5a.8xlarge (32 vCPU, 128 GiB) - m5a.12xlarge (48 vCPU, 192 GiB) - m5a.16xlarge (64 vCPU, 256 GiB)
#
#
# Question: Does ROSA support an air-gapped, disconnected environment where the ROSA cluster does not have internet access?
# ------------------------------------------------------------
# Answer:
# Answer: ROSA does not support an air-gapped, disconnected environment where the ROSA cluster does not have internet access. Egress can be limited to PrivateLink (for Red Hat SRE) and VPN or similar for customer access.
#
#
# Question: Is node autoscaling available?
# ------------------------------------------------------------
# Answer:
# Answer: Node autoscaling is available for OpenShift Enterprise on AWS clusters.
#
#
# Question: What is the maximum number of worker nodes that a cluster can support?
# ------------------------------------------------------------
# Answer:
# Answer: The maximum number of worker nodes that a cluster can support is 250.

# %% [markdown]
# # Conclusion
# Fine-tuning the T5 FLAN model using ROSA documentation data and evaluating its performance on the FAQ document, we observed that the fine-tuned model produced answers that were more relevant to the specific domain. This indicates that the model was able to learn domain-specific information and tailor its responses accordingly.
#
# Embedding search contexts further refined the answers generated by the fine-tuned model. This suggests that incorporating contextual information during the search process can improve the relevance and accuracy of the answers.
# Overall, the combination of fine-tuning the model with domain-specific data and leveraging embedding search contexts is a promising approach to question-answering systems in specialized domains such as ROSA documentation.
